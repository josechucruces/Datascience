# %% [markdown]
# ## Create a line plot

# %% [markdown]
# Thist tutotrial shows how to create a line plot

# %%
print ("A line plot : ")
# Out:
# A line plot :

# %%
a = [1, 2, 3, 4]
b = [-1, -2, -3, -4]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a,b)
plt.show()
